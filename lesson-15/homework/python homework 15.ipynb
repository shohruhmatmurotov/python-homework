# %%
import sqlite3

with sqlite3.connect('homework.db') as connection:
    cursor=connection.cursor()
    query="create table Roster1(name text, species text ,age int)"
    query1="insert into roster1 values('Benjamin Sisko','Human',40),('Jadzia Dax'	,'Trill',	300),('Kira Nerys',	'Bajoran',	29)"
    results=cursor.execute(query)
    cursor.execute(query1)
    query3="update roster1 set name='Ezri Daz' where name=Jadzia Dax"
    cursor.execute(query3)
    query4="select name,age where species= 'Bajoran'""homework clas 5.ipynb"
    cursor.execute(query4)
    cursor.close()
    cursor.commit()
    cursor.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[12], line 7
#       5 query="create table Roster1(name text, species text ,age int)"
#       6 query1="insert into roster1 values('Benjamin Sisko','Human',40)"
# ----> 7 results=cursor.execute(query)
#       8 cursor.execute(query1)
#       9 row=results.fetchall()
#
# OperationalError: table Roster1 already exists
