# %% [markdown]
# ## Pandas

# %%
with open("C:\\python\\movie.csv") as data_file:
    data = data_file.readlines(1)
    print(data)
# Out:
# ['color,director_name,num_critic_for_reviews,duration,director_facebook_likes,actor_3_facebook_likes,actor_2_name,actor_1_facebook_likes,gross,genres,actor_1_name,movie_title,num_voted_users,cast_total_facebook_likes,actor_3_name,facenumber_in_poster,plot_keywords,movie_imdb_link,num_user_for_reviews,language,country,content_rating,budget,title_year,actor_2_facebook_likes,imdb_score,aspect_ratio,movie_facebook_likes\n']

# %%
with open('data/movie.csv') as data_file:
    data = data_file.read()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 with open('data/movie.csv') as data_file:
# ----> 2     data = data_file.read()
#       3     print(data)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 486261: character maps to <undefined>

# %%
import pandas as pd

# %%
movies = pd.read_csv('data/movie.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
# 0, 1, 2, 3, 4 ... indexes / Axis 0
# color, director_name, num_critic_for_reviews ... columns / Axis 1
# Color, James Cameron ... values

# %%
movies.head() #by default first 5 values
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movies.head(10)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
movies.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
movies.tail(3)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                 genres  ...  \
# 4913                     0.0      NaN  Drama|Horror|Thriller  ...
# 4914                   946.0  10443.0   Comedy|Drama|Romance  ...
# 4915                    86.0  85222.0            Documentary  ...
#
#      num_user_for_reviews language  country  content_rating  budget  \
# 4913                  3.0  English      USA             NaN  1400.0
# ...

# %%
columns = movies.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
values = movies.values
values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
index = movies.index
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
print(type(columns))
print(type(values))
print(type(index))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'numpy.ndarray'>
# <class 'pandas.core.indexes.range.RangeIndex'>

# %%
#DataFrame
#Series

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies['content_rating'])
# Out:
# pandas.core.series.Series

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# Name: count, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
pd.Series(['Apple', None, 'Pear'])
# Out:
# 0    Apple
# 1     None
# 2     Pear
# dtype: object

# %%
movies.head(6)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
# 5                    475.0                   530.0   Samantha Morton
#
# ...

# %%
import numpy as np

# %%
pd.Series(['Apple', None, 'Pear', np.nan, 'Grape'])
# Out:
# 0    Apple
# 1     None
# 2     Pear
# 3      NaN
# 4    Grape
# dtype: object

# %%
pd.Series(['Apple', None, 'Pear', np.nan, 'Grape']).dtypes
# Out:
# dtype('O')

# %%
movies['director_name'] #shunaqa qilib alohida bitta columnni ajratib olishimiz mumkin
movies.director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies.director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies[['director_name', 'color']]
# Out:
#           director_name  color
# 0         James Cameron  Color
# 1        Gore Verbinski  Color
# 2            Sam Mendes  Color
# 3     Christopher Nolan  Color
# 4           Doug Walker    NaN
# ...                 ...    ...
# 4911        Scott Smith  Color
# 4912                NaN  Color
# 4913   Benjamin Roberds  Color
# 4914        Daniel Hsia  Color
# 4915           Jon Gunn  Color
#
# [4916 rows x 2 columns]

# %%
type(movies['director_name'])
# Out:
# pandas.core.series.Series

# %%
movies['director_name'].dtype
# Out:
# dtype('O')

# %%
type(movies[['director_name', 'color']]) #bu berilgan narsaning o'zining data typeni  chiqarib beradi 
movies['director_name'].dtype #bu ichidan chiqaryotgan dataning typeni chiqarib beradi
# Out:
# pandas.core.frame.DataFrame

# %%
movies['director_name'].size #bu rowlari sonini chiqarib beradi
# Out:
# 4916

# %%
movies['director_name'].name
# Out:
# 'director_name'

# %%
movies['director_name'].unique()
# Out:
# array(['James Cameron', 'Gore Verbinski', 'Sam Mendes', ...,
#        'Scott Smith', 'Benjamin Roberds', 'Daniel Hsia'], dtype=object)

# %%
director = movies['director_name']

# %%
director.head()
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
movies.sample(n=5)
# Out:
#                 color          director_name  num_critic_for_reviews  \
# 2718            Color  Gilles Paquet-Brenner                   136.0
# 2729  Black and White         Jon Turteltaub                    39.0
# 2176            Color        Jason Friedberg                   122.0
# 3631            Color      David F. Sandberg                   159.0
# 1234            Color         Clint Eastwood                   249.0
#
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 2718     111.0                     15.0                   121.0
# 2729      98.0                    226.0                   496.0
# 2176      82.0                     82.0                   354.0
# 3631      81.0                     26.0                   300.0
# 1234     134.0                  16000.0                   235.0
#
#          actor_2_name  actor_1_facebook_likes       gross  \
# 2718      Aidan Quinn                  1000.0   7691700.0
# ...

# %%
director.value_counts()
# Out:
# director_name
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        16
#                     ..
# John Putch           1
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: count, Length: 2397, dtype: int64

# %%
fb_likes = movies['actor_1_facebook_likes']
fb_likes.max()
fb_likes.mean() #bu o'rtachasini chiqarib beradi 
fb_likes.describe() #bu by defauly eng kerakli statistikalarini chiqarib beradi max ,min ,mean ..
director.isna()
director.isnull() #bu ikkitasiyam null yoki null emasligini tekshiradi va true yoki fasle chiqaradi

# %%
fb_likes.max()
# Out:
# 640000.0

# %%
fb_likes.mean()
# Out:
# 6494.488490527602

# %%
fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
# class 17

with open("C:\\python\\movie.csv") as data_file:
    data = data_file.readlines(1)
    print(data) #bu oddiy o'qib olish 
#pandas 
import pandas as pd
movies = pd.read_csv('data/movie.csv') #shu shaklda pandas bilan datani o'qib olamiz

movies.head() #by default first 5 values boshidan chiqarib beradi rowlarni 

movies.tail(3) # bu ohiridan chiqarib beradi 

movies.columns # bu faqat columnlarni array shaklida chiqarib beradi

movies.values # bu tableni hisobga olmagan holda tabledaki hamma valueslarni chiqarib beradi 

#Dataframe bu pandasdagi table 
#Series bu bitta columnni o'ziga aytiladi 

#pandasda objectbu string datatype 

movies.dtypes.value_counts() # bu kod dtypes bo'yicha gruhlab sanab berishi

movies.info() # bu tableni null bo'lmagan barcha malumotlarni chiqarib beradi 


pd.Series('pd.Series(['Apple', None, 'Pear'])') #shu orqali series yasab olinadi yani bitta column 

None #degan datatype mavjud 

import pandas as np
pd.Series(['Apple', None, 'Pear', np.nan, 'Grape']) #shunaqa qilib nan  datatypeni qo'yiladi bu degan sqldagi Nullga teng 

movies['director_name'] #shunaqa qilib alohida bitta columnni ajratib olishimiz mumkin
movies.director_name #bu bilan faqat 1 ta colummnni chiqarib ola olamiz

type(movies[['director_name', 'color']]) #bu berilgan narsaning o'zining data typeni  chiqarib beradi 
movies['director_name'].dtype #bu ichidan chiqaryotgan dataning typeni chiqarib beradi 

movies['director_name'].size #bu rowlari sonini chiqarib beradi 

movies['director_name'].name #column nameni chiqarib beradi 

movies['director_name'].unique() #arrayda unique datalarni chiqarib beradi 

movies.sample(n=5) #bu datalarni ichidan sample random rowlarni chiqarib  beradi 

director=movies['director_name']
director.value_counts()# bu datalarni necha marta kelganini chiqarib beradi yani directorname bo'yich group by qilib beradi 

fb_likes = movies['actor_1_facebook_likes']
fb_likes.max()
fb_likes.mean() #bu o'rtachasini chiqarib beradi 
fb_likes.describe() #bu by defauly eng kerakli statistikalarini chiqarib beradi max ,min ,mean ..
director.isna()
director.isnull() #bu ikkitasiyam null yoki null emasligini tekshiradi va true yoki fasle chiqaradi 

director.fillna(0) #bu datalari ichida null dataga 0 qo'yib chiqarib beradi lekin variabledagai dataga tasir qilmaydi 
director = director.fillna(0) #bu esa tasir  qiladi

fb_likes.count() #bu null bo'lmagan roqlarni sanaydi 
fb_likes.fillna(0).count() #hamma rowlarni sanaydi

fb_likes.dropna()#bu null yo'q rowlarni chiqarib beradi null larni chiqarib yuboradi rowlarini 
fb_likes=fb_likes.dropna() #bunday qilgandan keyingina tasir qiladi asosiy dataga 

imdb_score = movies['imdb_score']
imdb_score
imdb_score + 1 #bunday qilsak arraylar kabi hamma malumotga qo'shib beradi 

movies[movies['imdb_score'] > 8] #bu orqali filter beramiz

money.sub(15, fill_value=8) #ayrib beraid fill_value buyerda agar null data bo'lsa uni nolga o'zgartiib berishadi 

movies = movies.rename(columns={'director_name':'director', 'num_critic_for_reviews':'critic reviews'}) #columnlarning nomini ozgarturib beradi 

fb_likes.fillna(0).astype()#shunaqa qilib typelarini convert qilishimiz mumkin 

17.30

# %%
director = director.fillna(0).astype(int)

# %%
director
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                    0
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
fb_likes.fillna(0).count()
# Out:
# 4916

# %%
fb_likes.dropna()
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4909, dtype: float64

# %%
fb_likes
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64

# %%
imdb_score = movies['imdb_score']
imdb_score
imdb_score + 1
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score + 1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
movies[movies['imdb_score'] > 8]
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 3     Color  Christopher Nolan                   813.0     164.0
# 17    Color        Joss Whedon                   703.0     173.0
# 27    Color      Anthony Russo                   516.0     147.0
# 43    Color        Lee Unkrich                   453.0     103.0
# 58    Color     Andrew Stanton                   421.0      98.0
# ...     ...                ...                     ...       ...
# 4804  Color          Cary Bell                     NaN      78.0
# 4815  Color      Bill Melendez                    43.0      25.0
# 4822  Color    Amal Al-Agroobi                     NaN      62.0
# 4846  Color         Sut Jhally                    16.0      80.0
# 4875  Color    Martin Scorsese                    71.0     117.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 3                     22000.0                 23000.0      Christian Bale
# ...

# %%
money = pd.Series([100, 20, None])
money
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 money = pd.Series([100, 20, None])
#       2 money
#
# NameError: name 'pd' is not defined

# %%
money.sub(15, fill_value=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 money.sub(15, fill_value=8)
#
# NameError: name 'money' is not defined

# %%
secondmoney = pd.Series([50, 10, 4, 30])
secondmoney
# Out:
# 0    50
# 1    10
# 2     4
# 3    30
# dtype: int64

# %%
money + secondmoney
# Out:
# 0    150.0
# 1     30.0
# 2      NaN
# 3      NaN
# dtype: float64

# %%
fb_likes.fillna(0).astype(int)
# Out:
# 0        1000
# 1       40000
# 2       11000
# 3       27000
# 4         131
#         ...
# 4911      637
# 4912      841
# 4913        0
# 4914      946
# 4915       86
# Name: actor_1_facebook_likes, Length: 4916, dtype: int32

# %%
movies = movies.rename(columns={'director_name':'director', 'num_critic_for_reviews':'critic reviews'})

# %%
movies
# Out:
#       color           director  critic reviews  duration  \
# 0     Color      James Cameron           723.0     178.0
# 1     Color     Gore Verbinski           302.0     169.0
# 2     Color         Sam Mendes           602.0     148.0
# 3     Color  Christopher Nolan           813.0     164.0
# 4       NaN        Doug Walker             NaN       NaN
# ...     ...                ...             ...       ...
# 4911  Color        Scott Smith             1.0      87.0
# 4912  Color                NaN            43.0      43.0
# 4913  Color   Benjamin Roberds            13.0      76.0
# 4914  Color        Daniel Hsia            14.0     100.0
# 4915  Color           Jon Gunn            43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# ...

# %%
movies['viewed'] = 1

# %%
movies
# Out:
#       color           director  critic reviews  duration  \
# 0     Color      James Cameron           723.0     178.0
# 1     Color     Gore Verbinski           302.0     169.0
# 2     Color         Sam Mendes           602.0     148.0
# 3     Color  Christopher Nolan           813.0     164.0
# 4       NaN        Doug Walker             NaN       NaN
# ...     ...                ...             ...       ...
# 4911  Color        Scott Smith             1.0      87.0
# 4912  Color                NaN            43.0      43.0
# 4913  Color   Benjamin Roberds            13.0      76.0
# 4914  Color        Daniel Hsia            14.0     100.0
# 4915  Color           Jon Gunn            43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# ...

# %%
movies.drop(columns='viewed', inplace=True, errors='ignore')

# %%
movies.head(3)
# Out:
#    color        director  critic reviews  duration  director_facebook_likes  \
# 0  Color   James Cameron           723.0     178.0                      0.0
# 1  Color  Gore Verbinski           302.0     169.0                    563.0
# 2  Color      Sam Mendes           602.0     148.0                      0.0
#
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
#
#          gross                           genres  ... num_user_for_reviews  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...               3054.0
# 1  309404152.0         Action|Adventure|Fantasy  ...               1238.0
# 2  200074175.0        Action|Adventure|Thriller  ...                994.0
#
#   language  country  content_rating       budget  title_year  \
# ...

# %%
fname = ['McAtee', 'Fede', 'Richard', 'Weah']
lname = ['Freddie', 'Valve', 'Stark', 'Timoty']
birth = [2005, 1996, 1985, np.nan]

people = pd.DataFrame({'FirstName':fname, 'LastName':lname, 'BirthDate':birth})
people
# Out:
#   FirstName LastName  BirthDate
# 0    McAtee  Freddie     2005.0
# 1      Fede    Valve     1996.0
# 2   Richard    Stark     1985.0
# 3      Weah   Timoty        NaN

# %%
movies[movies.director == 'James Cameron']
# Out:
#       color       director  critic reviews  duration  director_facebook_likes  \
# 0     Color  James Cameron           723.0     178.0                      0.0
# 26    Color  James Cameron           315.0     194.0                      0.0
# 285   Color  James Cameron           210.0     153.0                      0.0
# 288   Color  James Cameron            94.0     141.0                      0.0
# 599   Color  James Cameron            82.0     171.0                      0.0
# 2455  Color  James Cameron           250.0     154.0                      0.0
# 3508  Color  James Cameron           204.0     107.0                      0.0
#
#       actor_3_facebook_likes       actor_2_name  actor_1_facebook_likes  \
# 0                      855.0   Joel David Moore                  1000.0
# 26                     794.0       Kate Winslet                 29000.0
# 285                    539.0  Jenette Goldstein                   780.0
# ...

# %%
movies[movies['director_facebook_likes'] == movies['director_facebook_likes'].max()]['director']
# Out:
# 3603    Joseph Gordon-Levitt
# Name: director, dtype: object

# %%
#1. Find the average temperature and the maximum one
#2. What was the weather condition on Monday
#3. What was the temperature on Friday in Farenheit

#20. +3

weather = pd.read_csv('weather_data.csv')
#1
print(weather['temp'].mean())
print(weather['temp'].max())

#2
print(weather[weather.day == 'Monday']['condition'])

#3
print(weather[weather.day == 'Friday']['temp']*9/5+32)
# Out:
# 14.0
# 20
# 0    Sunny
# Name: condition, dtype: object
# 4    66.2
# Name: temp, dtype: float64
